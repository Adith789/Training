# %% [markdown]
# <a href="https://colab.research.google.com/github/Adith789/Training/blob/main/Python_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=int(input("Enter total no. of monkeys:"))
k=int(input("Enter no. of banana monkey can eat:"))
j=int(input("Enter no. of peanut monkey can eat:"))
m=int(input("Enter total no. of banana:"))
p=int(input("Enter total no. of peanut:"))
if(k==0 or j==0):
  print("INVALID INPUT")
else:
  n=n-(m//k+p//j)
  if(m%k!=0 or p%k!=0):
    n=n-1
  print("No. of monkeys in tree:",n)
# Out:
# Enter total no. of monkeys:20
# Enter no. of banana monkey can eat:2
# Enter no. of peanut monkey can eat:3
# Enter total no. of banana:12
# Enter total no. of peanut:12
# No. of monkeys in tree: 10

# %%
print("Using Temp")
a,b=10,5
temp=a
a=b
b=temp
print(a,b)
print("Using ,")
a,b=10,5
a,b=b,a
print(a,b)
print("Using + and -")
a,b=10,5
a=a+b
b=a-b
a=a-b
print(a,b)
print("Using ^")
a,b=10,5
a=a^b
b=a^b
a=a^b
print(a,b)
# Out:
# Using Temp
# 5 10
# Using ,
# 5 10
# Using + and -
# 5 10
# Using ^
# 5 10

# %%
N=int(input("Enter max no. of candies:"))
K=int(input("Enter min no. of candies:"))
C=1
R=N
while(C==1):
  M=int(input("Enter amout of candies needed:"))
  if(M>=N):
    print("invalid")
  else:
    R=R-M
    if(R<=K):
      R=N
    print("SOLD=",M)
    print("Remaining=",R)
    C=int(input("DO you want to continue(1or0):"))
# Out:
# SOLD= 3
# Remaining= 7
# invalid
# SOLD= 0
# Remaining= 7

# %%
str=input("Ente a string:")
print(str[::-1])
# Out:
# Ente a string:Hello
# olleH

# %%
n=int(input("Enter a number:"))
while(n>0):
  r=n%10
  t=(t*10)+r
  n=n//10
print(t)
# Out:
# Enter a number:542
# 245

# %%
n=int(input("Enter a number:"))
t=0
while(n>0):
  r=n%10
  t=t+r
  n=n//10
print(t)
# Out:
# Enter a number:693
# 18

# %%
n=int(input("Enter a number:"))
t=0
while(n>0):
  r=n%10
  if(r>t):
    t=r
  n=n//10
print(t)
# Out:
# Enter a number:245
# 5

# %%
n=int(input("Enter a number:"))
a=n
t=0
while(n>0):
  r=n%10
  t=(t*10)+r
  n=n//10
if(a==t):
  print("Palindrome")
else:
  print("Not Palindrome")
# Out:
# Enter a number:121
# Palindrome

# %%
str=input("Ente a string:")
if(str==str[::-1]):
  print("Palindrome")
else:
  print("Not palindrome")
# Out:
# Ente a string:aikje
# Not palindrome

# %%
s1=input("Ënter a string:")
s2=input("Ënter another string:")
if(sorted(s1)!=sorted(s2)):
  print("Not anagram")
else:
  print("Anagram")
# Out:
# Ënter a string:listen
# Ënter another string:silent
# Anagram

# %%
str=input("Ënter a string:")
print("Length of string with built in:",len(str))
c=0
for i in str:
  c=c+1
print("Length of string without built in:",c)
# Out:
# Ënter a string:hello
# Length of string with built in: 5
# Length of string without built in: 5

# %%
s=input("Ënter a string:")
st=""
for i in str:
    if(i not in st):
      st+=i
print(st)
# Out:
# Ënter a string:abcdaab
# abchd

# %%
s=input("Ënter a string:")
v=0
c=0
for i in s:
  if(i in "aeiouAEIOU"):
    v+=1
  else:
    c+=1
print("No. of vowels:",v)
print("No of consonants:",c)
# Out:
# Ënter a string:Hello
# No. of vowels: 2
# No of consonants: 3

# %%
s=input("Ënter a string:")
s1=""
for i in s:
  if(i!=" "):
    s1+=i
print(s1)
# Out:
# Ënter a string:I am Abc
# IamAbc
